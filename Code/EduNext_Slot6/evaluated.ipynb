# %%
from tensorflow.keras.models import load_model
from Preprocessing.data_augmentation import *

import pandas as pd
import numpy as np
import os
# Out:
# Found 2000 images belonging to 2 classes.
# {'cat': 0, 'dog': 1}
# Found 500 images belonging to 2 classes.
# {'cat': 0, 'dog': 1}
# Found 500 images belonging to 2 classes.
# {'cat': 0, 'dog': 1}

# %%
result_csv = pd.read_csv('Models/model/log.csv')
result_csv
# Out:
#     epoch  accuracy  learning_rate      loss  val_accuracy  val_loss
# 0       0  0.596545       0.001000  0.894508      0.533333  0.697947
# 1       1  0.625000       0.001000  0.788019      0.500000  0.769640
# 2       2  0.637195       0.001000  0.703446      0.500000  2.802812
# 3       3  0.593750       0.001000  0.596946      0.500000  2.590099
# 4       4  0.667175       0.001000  0.630696      0.508333  1.347046
# 5       5  0.625000       0.000750  0.670954      0.300000  2.015949
# 6       6  0.682927       0.000750  0.613177      0.529167  1.062040
# 7       7  0.687500       0.000750  0.543712      0.300000  1.413893
# 8       8  0.715447       0.000750  0.586789      0.595833  0.862323
# 9       9  0.625000       0.000750  0.643612      0.600000  0.648200
# 10     10  0.721037       0.000750  0.543000      0.558333  0.876456
# 11     11  0.656250       0.000750  0.584403      0.600000  0.869296
# 12     12  0.729675       0.000750  0.532879      0.597917  0.875138
# ...

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.figure(figsize=(12, 6))
plt.plot(result_csv['epoch'], result_csv['accuracy'], label='Training Accuracy')
plt.plot(result_csv['epoch'], result_csv['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.figure(figsize=(12, 6))
plt.plot(result_csv['epoch'], result_csv['loss'], label='Training Loss')
plt.plot(result_csv['epoch'], result_csv['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
